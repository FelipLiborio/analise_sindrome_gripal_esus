# %%
import pandas as pd

# %%
df = pd.read_csv('../data/main/data_tratado.csv')

# %%
df.shape
# Out:
# (148733, 33)

# %%
df.columns
# Out:
# Index(['sintomas', 'profissionalSaude', 'racaCor', 'profissionalSeguranca',
#        'sexo', 'estado', 'municipio', 'origem', 'evolucaoCaso',
#        'classificacaoFinal', 'codigoEstrategiaCovid',
#        'codigoLocalRealizacaoTestagem', 'codigoRecebeuVacina',
#        'codigoLaboratorioPrimeiraDose', 'codigoLaboratorioSegundaDose',
#        'lotePrimeiraDose', 'loteSegundaDose',
#        'codigoContemComunidadeTradicional', 'excluido', 'validado',
#        'codigoDosesVacina', 'totalTestesRealizados', 'dataNotificacao',
#        'dataInicioSintomas', 'dataEncerramento', 'dataPrimeiraDose',
#        'dataSegundaDose', 'codigoEstadoTeste1', 'codigoTipoTeste1',
#        'codigoFabricanteTeste1', 'codigoResultadoTeste1', 'dataColetaTeste1',
#        'idade'],
#       dtype='object')
